# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading https://files.pythonhosted.org/packages/2e/48/0db29040c92726fcc6f99a5bc89e0ea8cf5a9d84753ebaaf53108792da2a/chembl-webresource-client-0.10.2.tar.gz (51kB)
#      |████████████████████████████████| 61kB 4.5MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from chembl_webresource_client) (1.24.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.6/dist-packages (from chembl_webresource_client) (2.23.0)
# Collecting requests-cache>=0.4.7
#   Downloading https://files.pythonhosted.org/packages/7f/55/9b1c40eb83c16d8fc79c5f6c2ffade04208b080670fbfc35e0a5effb5a92/requests_cache-0.5.2-py2.py3-none-any.whl
# Requirement already satisfied: easydict in /usr/local/lib/python3.6/dist-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Building wheels for collected packages: chembl-webresource-client
#   Building wheel for chembl-webresource-client (setup.py) ... done
#   Created wheel for chembl-webresource-client: filename=chembl_webresource_client-0.10.2-cp36-none-any.whl size=55663 sha256=b423b24edba6bf612b8c3bb7bfe49bb782e5712418e2090820439be0dd1bf15b
#   Stored in directory: /root/.cache/pip/wheels/e6/96/19/3f042bfda7c669bfe24c8278477f57b0fbbf3e488b4c09e3a8
# Successfully built chembl-webresource-client
# Installing collected packages: requests-cache, chembl-webresource-client
# Successfully installed chembl-webresource-client-0.10.2 requests-cache-0.5.2

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
#target search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  ...   tax_id
# 0                                                 []  ...    11119
# 1                                                 []  ...   227859
# 2                                                 []  ...    12663
# 3                                                 []  ...    11137
# 4  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...  ...   227859
# 5                                                 []  ...  1335626
# 6  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...  ...   227859
#
# [7 rows x 9 columns]

# %% [markdown]
# 'Select and retrieve bioactivity for "SARS coronavirus 3C-like protienase(fifth entry)"'

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL3927'

# %% [markdown]
# we will assign the fifth entry(which corresponds to the target protien, coronavirus 3C-like proteinase) to selected_target variable

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id = selected_target).filter(standard_type = "IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   activity_comment  activity_id  ... upper_value value
# 0             None      1480935  ...        None   7.2
# 1             None      1480936  ...        None   9.4
# 2             None      1481061  ...        None  13.5
#
# [3 rows x 43 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.to_csv('bioactivity_data.csv',index = False)

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data’: File exists

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/ data"

# %%
# !cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
# !ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 79
# -rw------- 1 root root 70010 Jan 24 05:39 bioactivity_data.csv
# -rw------- 1 root root 10567 Jan 24 04:50 bioactivity_preprocessed_data.csv

# %%
# !ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %%
! head bioactivity_data.csv
# Out:
# activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,1480935,[],CHEMBL829584,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease),B,BAO_0000190,BAO_0000357,single protein format,Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21,,,CHEMBL1139624,Bioorg. Med. Chem. Lett.,2005,"{'bei': '18.28', 'le': '0.33', 'lle': '3.25', 'sei': '5.90'}",CHEMBL187579,,CHEMBL187579,5.14,False,http://www.openphacts.org/units/Nanomolar,384103,=,1,True,=,,IC50,nM,,7200.0,CHEMBL3927,SARS coronavirus,SARS coronavirus 3C-like proteinase,227859,,,IC50,uM,UO_0000065,,7.2
# ,1480936,[],CHEMBL829584,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease),B,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21,,,CHEMBL1139624,Bioorg. Med. Chem. Lett.,2005,"{'bei': '12.10', 'le': '0.33', 'lle': '1.22', 'sei': '13.45'}",CHEMBL188487,,CHEMBL188487,5.03,False,http://www.openphacts.org/units/Nanomolar,383984,=,1,True,=,,IC50,nM,,9400.0,CHEMBL3927,SARS coronavirus,SARS coronavirus 3C-like proteinase,227859,,,IC50,uM,UO_0000065,,9.4
# ,1481061,[],CHEMBL830868,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease) at 20 uM,B,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21,,,CHEMBL1139624,Bioorg. Med. Chem. Lett.,2005,"{'bei': '11.56', 'le': '0.29', 'lle': '2.21', 'sei': '8.72'}",CHEMBL185698,,CHEMBL185698,4.87,False,http://www.openphacts.org/units/Nanomolar,384106,=,1,True,=,,IC50,nM,,13500.0,CHEMBL3927,SARS coronavirus,SARS coronavirus 3C-like proteinase,227859,,,IC50,uM,UO_0000065,,13.5
# ,1481065,[],CHEMBL829584,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease),B,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21,,,CHEMBL1139624,Bioorg. Med. Chem. Lett.,2005,"{'bei': '16.64', 'le': '0.32', 'lle': '1.25', 'sei': '13.06'}",CHEMBL426082,,CHEMBL426082,4.88,False,http://www.openphacts.org/units/Nanomolar,384075,=,1,True,=,,IC50,nM,,13110.0,CHEMBL3927,SARS coronavirus,SARS coronavirus 3C-like proteinase,227859,,,IC50,uM,UO_0000065,,13.11
# ,1481066,[],CHEMBL829584,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease),B,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-],,,CHEMBL1139624,Bioorg. Med. Chem. Lett.,2005,"{'bei': '16.84', 'le': '0.32', 'lle': '2.16', 'sei': '7.08'}",CHEMBL187717,,CHEMBL187717,5.70,False,http://www.openphacts.org/units/Nanomolar,384234,=,1,True,=,,IC50,nM,,2000.0,CHEMBL3927,SARS coronavirus,SARS coronavirus 3C-like proteinase,227859,,,IC50,uM,UO_0000065,,2.0
# ,1481068,[],CHEMBL828143,In vitro inhibitory concentration SARS coronavirus main protease (SARS CoV 3C-like protease) ,B,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(Cc2cc3ccccc3s2)c2c(Br)cccc21,,,CHEMBL1139624,Bioorg. Med. Chem. Lett.,2005,"{'bei': '16.14', 'le': '0.37', 'lle': '1.62', 'sei': '16.07'}",CHEMBL365134,,CHEMBL365134,6.01,False,http://www.openphacts.org/units/Nanomolar,384081,=,1,True,=,,IC50,nM,,980.0,CHEMBL3927,SARS coronavirus,SARS coronavirus 3C-like proteinase,227859,,,IC50,uM,UO_0000065,,0.98
# ,1481088,[],CHEMBL829584,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease),B,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccc(F)cc21,,,CHEMBL1139624,Bioorg. Med. Chem. Lett.,2005,"{'bei': '17.08', 'le': '0.33', 'lle': '1.55', 'sei': '14.22'}",CHEMBL187598,,CHEMBL187598,5.32,False,http://www.openphacts.org/units/Nanomolar,384303,=,1,True,=,,IC50,nM,,4820.0,CHEMBL3927,SARS coronavirus,SARS coronavirus 3C-like proteinase,227859,,,IC50,uM,UO_0000065,,4.82
# ,1481089,[],CHEMBL829584,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease),B,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccc(I)cc21,,,CHEMBL1139624,Bioorg. Med. Chem. Lett.,2005,"{'bei': '14.36', 'le': '0.37', 'lle': '1.78', 'sei': '16.11'}",CHEMBL190743,,CHEMBL190743,6.02,False,http://www.openphacts.org/units/Nanomolar,384329,=,1,True,=,,IC50,nM,,950.0,CHEMBL3927,SARS coronavirus,SARS coronavirus 3C-like proteinase,227859,,,IC50,uM,UO_0000065,,0.95
# ,1481093,[],CHEMBL829584,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease),B,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(Cc2cc3ccccc3s2)c2cccc(Cl)c21,,,CHEMBL1139624,Bioorg. Med. Chem. Lett.,2005,"{'bei': '15.10', 'le': '0.31', 'lle': '0.67', 'sei': '13.24'}",CHEMBL365469,,CHEMBL365469,4.95,False,http://www.openphacts.org/units/Nanomolar,384283,=,1,True,=,,IC50,nM,,11200.0,CHEMBL3927,SARS coronavirus,SARS coronavirus 3C-like proteinase,227859,,,IC50,uM,UO_0000065,,11.2

# %% [markdown]
# handling missing data

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#     activity_comment  activity_id  ... upper_value  value
# 0               None      1480935  ...        None    7.2
# 1               None      1480936  ...        None    9.4
# 2               None      1481061  ...        None   13.5
# 3               None      1481065  ...        None  13.11
# 4               None      1481066  ...        None    2.0
# ..               ...          ...  ...         ...    ...
# 128             None     12041507  ...        None   10.6
# 129             None     12041508  ...        None   10.1
# 130             None     12041509  ...        None   11.5
# 131             None     12041510  ...        None   10.7
# 132             None     12041511  ...        None   78.9
#
# [133 rows x 43 columns]

# %% [markdown]
# preprocessing of bioactivity data

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# iterate the molecule_chembl_id to a list

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# iterate canonical_smiles to a list

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# iterate standard_value to a list

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# *better* *method*

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]

# %%
df3
# Out:
#     molecule_chembl_id  ... standard_value
# 0         CHEMBL187579  ...         7200.0
# 1         CHEMBL188487  ...         9400.0
# 2         CHEMBL185698  ...        13500.0
# 3         CHEMBL426082  ...        13110.0
# 4         CHEMBL187717  ...         2000.0
# ..                 ...  ...            ...
# 128      CHEMBL2146517  ...        10600.0
# 129       CHEMBL187460  ...        10100.0
# 130       CHEMBL363535  ...        11500.0
# 131       CHEMBL227075  ...        10700.0
# 132        CHEMBL45830  ...        78900.0
#
# [133 rows x 3 columns]

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples, columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#     molecule_chembl_id  ... standard_value
# 0         CHEMBL187579  ...         7200.0
# 1         CHEMBL188487  ...         9400.0
# 2         CHEMBL185698  ...        13500.0
# 3         CHEMBL426082  ...        13110.0
# 4         CHEMBL187717  ...         2000.0
# ..                 ...  ...            ...
# 128      CHEMBL2146517  ...        10600.0
# 129       CHEMBL187460  ...        10100.0
# 130       CHEMBL363535  ...        11500.0
# 131       CHEMBL227075  ...        10700.0
# 132        CHEMBL45830  ...        78900.0
#
# [133 rows x 4 columns]

# %%
df3. to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
# !ls -l
# Out:
# total 92
# -rw-r--r-- 1 root root 70010 Jan 24 05:38 bioactivity_data.csv
# -rw-r--r-- 1 root root 10567 Jan 24 05:39 bioactivity_preprocessed_data.csv
# drwx------ 5 root root  4096 Jan 24 05:38 gdrive
# drwxr-xr-x 1 root root  4096 Jan 20 17:27 sample_data

# %% [markdown]
# copying data to google drive

# %%
# !cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
# !ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
! conda install -c rdkit rdkit -y
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2021-01-24 05:39:02--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   114MB/s    in 0.7s
#
# 2021-01-24 05:39:02 (114 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.0=py37h7b6447c_0
#     - conda==4.8.2=py37_0
#     - cryptography==2.8=py37h1ba5d50_0
#     - idna==2.8=py37_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py37_1
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.19=py37_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.6=h0371630_2
#     - readline==7.0=h7b6447c_5
#     - requests==2.22.0=py37_1
#     - ruamel_yaml==0.15.87=py37h7b6447c_0
#     - setuptools==45.2.0=py37_0
#     - six==1.14.0=py37_0
#     - sqlite==3.31.1=h7b6447c_0
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.42.1=py_0
#     - urllib3==1.25.8=py37_0
#     - wheel==0.34.2=py37_0
#     - xz==5.2.4=h14c3975_4
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   asn1crypto         pkgs/main/linux-64::asn1crypto-1.3.0-py37_0
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2020.1.1-0
#   certifi            pkgs/main/linux-64::certifi-2019.11.28-py37_0
#   cffi               pkgs/main/linux-64::cffi-1.14.0-py37h2e261b9_0
#   chardet            pkgs/main/linux-64::chardet-3.0.4-py37_1003
#   conda              pkgs/main/linux-64::conda-4.8.2-py37_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.6.0-py37h7b6447c_0
#   cryptography       pkgs/main/linux-64::cryptography-2.8-py37h1ba5d50_0
#   idna               pkgs/main/linux-64::idna-2.8-py37_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7
#   libedit            pkgs/main/linux-64::libedit-3.1.20181209-hc058e9b_0
#   libffi             pkgs/main/linux-64::libffi-3.2.1-hd88cf55_4
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.1.0-hdf63c60_0
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.1.0-hdf63c60_0
#   ncurses            pkgs/main/linux-64::ncurses-6.2-he6710b0_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1d-h7b6447c_4
#   pip                pkgs/main/linux-64::pip-20.0.2-py37_1
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py37h7b6447c_0
#   pycparser          pkgs/main/linux-64::pycparser-2.19-py37_0
#   pyopenssl          pkgs/main/linux-64::pyopenssl-19.1.0-py37_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py37_0
#   python             pkgs/main/linux-64::python-3.7.6-h0371630_2
#   readline           pkgs/main/linux-64::readline-7.0-h7b6447c_5
#   requests           pkgs/main/linux-64::requests-2.22.0-py37_1
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.87-py37h7b6447c_0
#   setuptools         pkgs/main/linux-64::setuptools-45.2.0-py37_0
#   six                pkgs/main/linux-64::six-1.14.0-py37_0
#   sqlite             pkgs/main/linux-64::sqlite-3.31.1-h7b6447c_0
#   tk                 pkgs/main/linux-64::tk-8.6.8-hbc83047_0
#   tqdm               pkgs/main/noarch::tqdm-4.42.1-py_0
#   urllib3            pkgs/main/linux-64::urllib3-1.25.8-py37_0
#   wheel              pkgs/main/linux-64::wheel-0.34.2-py37_0
#   xz                 pkgs/main/linux-64::xz-5.2.4-h14c3975_4
#   yaml               pkgs/main/linux-64::yaml-0.1.7-had09818_2
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     bzip2-1.0.8                |       h7b6447c_0          78 KB
#     ca-certificates-2021.1.19  |       h06a4308_0         121 KB
#     cairo-1.14.12              |       h8948797_3         906 KB
#     certifi-2020.12.5          |   py37h06a4308_0         141 KB
#     conda-4.9.2                |   py37h06a4308_0         2.9 MB
#     fontconfig-2.13.0          |       h9420a91_0         227 KB
#     freetype-2.10.4            |       h5ab3b9f_0         596 KB
#     glib-2.66.1                |       h92f7085_0         2.9 MB
#     icu-58.2                   |       he6710b0_3        10.5 MB
#     intel-openmp-2020.2        |              254         786 KB
#     jpeg-9b                    |       h024ee3a_2         214 KB
#     lcms2-2.11                 |       h396b838_0         307 KB
#     libboost-1.73.0            |      hf484d3e_11        13.9 MB
#     libffi-3.3                 |       he6710b0_2          50 KB
#     libpng-1.6.37              |       hbc83047_0         278 KB
#     libtiff-4.1.0              |       h2733197_1         449 KB
#     libuuid-1.0.3              |       h1bed415_2          15 KB
#     libxcb-1.14                |       h7b6447c_0         505 KB
#     libxml2-2.9.10             |       hb55368b_3         1.2 MB
#     lz4-c-1.9.3                |       h2531618_0         186 KB
#     mkl-2020.2                 |              256       138.3 MB
#     mkl-service-2.3.0          |   py37he8ac12f_0          52 KB
#     mkl_fft-1.2.0              |   py37h23d657b_0         148 KB
#     mkl_random-1.1.1           |   py37h0573a6f_0         322 KB
#     numpy-1.19.2               |   py37h54aff64_0          22 KB
#     numpy-base-1.19.2          |   py37hfa32c7d_0         4.1 MB
#     olefile-0.46               |           py37_0          50 KB
#     openssl-1.1.1i             |       h27cfd23_0         2.5 MB
#     pandas-1.2.1               |   py37ha9443f7_0         8.5 MB
#     pcre-8.44                  |       he6710b0_0         212 KB
#     pillow-8.1.0               |   py37he98fc37_0         623 KB
#     pixman-0.40.0              |       h7b6447c_0         370 KB
#     py-boost-1.73.0            |  py37h04863e7_11         202 KB
#     python-dateutil-2.8.1      |             py_0         215 KB
#     pytz-2020.5                |     pyhd3eb1b0_0         182 KB
#     rdkit-2020.09.1.0          |   py37hd50e099_1        25.8 MB  rdkit
#     xz-5.2.5                   |       h7b6447c_0         341 KB
#     zstd-1.4.5                 |       h9ceee32_0         619 KB
#     ------------------------------------------------------------
#                                            Total:       218.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h7b6447c_0
#   cairo              pkgs/main/linux-64::cairo-1.14.12-h8948797_3
#   fontconfig         pkgs/main/linux-64::fontconfig-2.13.0-h9420a91_0
#   freetype           pkgs/main/linux-64::freetype-2.10.4-h5ab3b9f_0
#   glib               pkgs/main/linux-64::glib-2.66.1-h92f7085_0
#   icu                pkgs/main/linux-64::icu-58.2-he6710b0_3
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2020.2-254
#   jpeg               pkgs/main/linux-64::jpeg-9b-h024ee3a_2
#   lcms2              pkgs/main/linux-64::lcms2-2.11-h396b838_0
#   libboost           pkgs/main/linux-64::libboost-1.73.0-hf484d3e_11
#   libpng             pkgs/main/linux-64::libpng-1.6.37-hbc83047_0
#   libtiff            pkgs/main/linux-64::libtiff-4.1.0-h2733197_1
#   libuuid            pkgs/main/linux-64::libuuid-1.0.3-h1bed415_2
#   libxcb             pkgs/main/linux-64::libxcb-1.14-h7b6447c_0
#   libxml2            pkgs/main/linux-64::libxml2-2.9.10-hb55368b_3
#   lz4-c              pkgs/main/linux-64::lz4-c-1.9.3-h2531618_0
#   mkl                pkgs/main/linux-64::mkl-2020.2-256
#   mkl-service        pkgs/main/linux-64::mkl-service-2.3.0-py37he8ac12f_0
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.2.0-py37h23d657b_0
#   mkl_random         pkgs/main/linux-64::mkl_random-1.1.1-py37h0573a6f_0
#   numpy              pkgs/main/linux-64::numpy-1.19.2-py37h54aff64_0
#   numpy-base         pkgs/main/linux-64::numpy-base-1.19.2-py37hfa32c7d_0
#   olefile            pkgs/main/linux-64::olefile-0.46-py37_0
#   pandas             pkgs/main/linux-64::pandas-1.2.1-py37ha9443f7_0
#   pcre               pkgs/main/linux-64::pcre-8.44-he6710b0_0
#   pillow             pkgs/main/linux-64::pillow-8.1.0-py37he98fc37_0
#   pixman             pkgs/main/linux-64::pixman-0.40.0-h7b6447c_0
#   py-boost           pkgs/main/linux-64::py-boost-1.73.0-py37h04863e7_11
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8.1-py_0
#   pytz               pkgs/main/noarch::pytz-2020.5-pyhd3eb1b0_0
#   rdkit              rdkit/linux-64::rdkit-2020.09.1.0-py37hd50e099_1
#   zstd               pkgs/main/linux-64::zstd-1.4.5-h9ceee32_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                                2020.1.1-0 --> 2021.1.19-h06a4308_0
#   certifi                                 2019.11.28-py37_0 --> 2020.12.5-py37h06a4308_0
#   conda                                        4.8.2-py37_0 --> 4.9.2-py37h06a4308_0
#   libffi                                   3.2.1-hd88cf55_4 --> 3.3-he6710b0_2
#   openssl                                 1.1.1d-h7b6447c_4 --> 1.1.1i-h27cfd23_0
#   xz                                       5.2.4-h14c3975_4 --> 5.2.5-h7b6447c_0
#
#
#
# Downloading and Extracting Packages
# pixman-0.40.0        | 370 KB    | : 100% 1.0/1 [00:00<00:00,  4.93it/s]
# xz-5.2.5             | 341 KB    | : 100% 1.0/1 [00:00<00:00, 10.73it/s]
# libboost-1.73.0      | 13.9 MB   | : 100% 1.0/1 [00:02<00:00,  2.10s/it]
# libtiff-4.1.0        | 449 KB    | : 100% 1.0/1 [00:00<00:00, 12.41it/s]
# fontconfig-2.13.0    | 227 KB    | : 100% 1.0/1 [00:00<00:00, 13.41it/s]
# bzip2-1.0.8          | 78 KB     | : 100% 1.0/1 [00:00<00:00, 14.20it/s]
# freetype-2.10.4      | 596 KB    | : 100% 1.0/1 [00:00<00:00, 11.86it/s]
# libffi-3.3           | 50 KB     | : 100% 1.0/1 [00:00<00:00, 14.29it/s]
# lcms2-2.11           | 307 KB    | : 100% 1.0/1 [00:00<00:00, 14.35it/s]
# numpy-base-1.19.2    | 4.1 MB    | : 100% 1.0/1 [00:00<00:00,  3.88it/s]
# olefile-0.46         | 50 KB     | : 100% 1.0/1 [00:00<00:00, 12.25it/s]
# pytz-2020.5          | 182 KB    | : 100% 1.0/1 [00:00<00:00,  3.78it/s]
# certifi-2020.12.5    | 141 KB    | : 100% 1.0/1 [00:00<00:00, 13.78it/s]
# blas-1.0             | 6 KB      | : 100% 1.0/1 [00:00<00:00, 16.02it/s]
# conda-4.9.2          | 2.9 MB    | : 100% 1.0/1 [00:00<00:00,  5.35it/s]
# pandas-1.2.1         | 8.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.57it/s]
# libxml2-2.9.10       | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  6.95it/s]
# jpeg-9b              | 214 KB    | : 100% 1.0/1 [00:00<00:00, 11.81it/s]
# zstd-1.4.5           | 619 KB    | : 100% 1.0/1 [00:00<00:00, 12.11it/s]
# py-boost-1.73.0      | 202 KB    | : 100% 1.0/1 [00:00<00:00, 11.15it/s]
# mkl-service-2.3.0    | 52 KB     | : 100% 1.0/1 [00:00<00:00, 12.64it/s]
# rdkit-2020.09.1.0    | 25.8 MB   | : 100% 1.0/1 [00:26<00:00, 26.78s/it]
# intel-openmp-2020.2  | 786 KB    | : 100% 1.0/1 [00:00<00:00, 11.10it/s]
# python-dateutil-2.8. | 215 KB    | : 100% 1.0/1 [00:00<00:00, 14.37it/s]
# mkl_fft-1.2.0        | 148 KB    | : 100% 1.0/1 [00:00<00:00, 14.15it/s]
# cairo-1.14.12        | 906 KB    | : 100% 1.0/1 [00:00<00:00,  9.91it/s]
# pillow-8.1.0         | 623 KB    | : 100% 1.0/1 [00:00<00:00, 11.04it/s]
# lz4-c-1.9.3          | 186 KB    | : 100% 1.0/1 [00:00<00:00, 14.50it/s]
# glib-2.66.1          | 2.9 MB    | : 100% 1.0/1 [00:00<00:00,  5.03it/s]
# ca-certificates-2021 | 121 KB    | : 100% 1.0/1 [00:00<00:00, 11.79it/s]
# pcre-8.44            | 212 KB    | : 100% 1.0/1 [00:00<00:00, 14.92it/s]
# mkl-2020.2           | 138.3 MB  | : 100% 1.0/1 [00:05<00:00,  5.43s/it]
# mkl_random-1.1.1     | 322 KB    | : 100% 1.0/1 [00:00<00:00, 12.02it/s]
# openssl-1.1.1i       | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  5.64it/s]
# libxcb-1.14          | 505 KB    | : 100% 1.0/1 [00:00<00:00, 11.21it/s]
# libpng-1.6.37        | 278 KB    | : 100% 1.0/1 [00:00<00:00, 12.21it/s]
# libuuid-1.0.3        | 15 KB     | : 100% 1.0/1 [00:00<00:00, 13.79it/s]
# numpy-1.19.2         | 22 KB     | : 100% 1.0/1 [00:00<00:00, 16.39it/s]
# icu-58.2             | 10.5 MB   | : 100% 1.0/1 [00:00<00:00,  2.09it/s]
# done
# done
# done

# %%
df = pd.read_csv('bioactivity_preprocessed_data.csv')

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %%
def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem) 
        moldata.append(mol)
       
    baseData= np.arange(1,1)
    i=0  
    for mol in moldata:        
       
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
           
        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])   
    
        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1      
    
    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]   
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)
    
    return descriptors

# %%
df_lipinski = lipinski(df.canonical_smiles)

# %%
df_lipinski
# Out:
#           MW     LogP  NumHDonors  NumHAcceptors
# 0    281.271  1.89262         0.0            5.0
# 1    415.589  3.81320         0.0            2.0
# 2    421.190  2.66050         0.0            4.0
# 3    293.347  3.63080         0.0            3.0
# 4    338.344  3.53900         0.0            5.0
# ..       ...      ...         ...            ...
# 128  338.359  3.40102         0.0            5.0
# 129  296.366  3.44330         0.0            3.0
# 130  276.291  4.09564         0.0            3.0
# 131  278.307  3.29102         0.0            3.0
# 132  282.383  4.10530         0.0            2.0
#
# [133 rows x 4 columns]

# %%
df_combined = pd.concat([df, df_lipinski], axis=1)
df_combined
# Out:
#     molecule_chembl_id  ... NumHAcceptors
# 0         CHEMBL187579  ...           5.0
# 1         CHEMBL188487  ...           2.0
# 2         CHEMBL185698  ...           4.0
# 3         CHEMBL426082  ...           3.0
# 4         CHEMBL187717  ...           5.0
# ..                 ...  ...           ...
# 128      CHEMBL2146517  ...           5.0
# 129       CHEMBL187460  ...           3.0
# 130       CHEMBL363535  ...           3.0
# 131       CHEMBL227075  ...           3.0
# 132        CHEMBL45830  ...           2.0
#
# [133 rows x 8 columns]

# %% [markdown]
# convrting ic50 to pic50

# %%
import numpy as np

def pIC50(input):
    pIC50 = []

    for i in input['standard_value_norm']:
        molar = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50
    x = input.drop('standard_value_norm', 1)
        
    return x

# %%
df_combined.standard_value.describe()
# Out:
# count    1.330000e+02
# mean     8.017926e+12
# std      3.344888e+13
# min      5.000000e+01
# 25%      1.070000e+04
# 50%      2.350000e+04
# 75%      3.000000e+05
# max      3.311311e+14
# Name: standard_value, dtype: float64

# %%
def norm_value(input):
  norm = []

  for i in input['standard_value']:
    if i > 100000000:
      i = 100000000
    norm.append(i)

  input['standard_value_norm'] = norm
  x = input.drop('standard_value', 1)

  return x

# %%
df_norm = norm_value(df_combined)

# %%
df_norm
# Out:
#     molecule_chembl_id  ... standard_value_norm
# 0         CHEMBL187579  ...              7200.0
# 1         CHEMBL188487  ...              9400.0
# 2         CHEMBL185698  ...             13500.0
# 3         CHEMBL426082  ...             13110.0
# 4         CHEMBL187717  ...              2000.0
# ..                 ...  ...                 ...
# 128      CHEMBL2146517  ...             10600.0
# 129       CHEMBL187460  ...             10100.0
# 130       CHEMBL363535  ...             11500.0
# 131       CHEMBL227075  ...             10700.0
# 132        CHEMBL45830  ...             78900.0
#
# [133 rows x 8 columns]

# %%
df_norm.standard_value_norm.describe()
# Out:
# count    1.330000e+02
# mean     2.110164e+07
# std      4.089714e+07
# min      5.000000e+01
# 25%      1.070000e+04
# 50%      2.350000e+04
# 75%      3.000000e+05
# max      1.000000e+08
# Name: standard_value_norm, dtype: float64

# %%
df_final = pIC50(df_norm)
df_final
# Out:
#     molecule_chembl_id  ...     pIC50
# 0         CHEMBL187579  ...  5.142668
# 1         CHEMBL188487  ...  5.026872
# 2         CHEMBL185698  ...  4.869666
# 3         CHEMBL426082  ...  4.882397
# 4         CHEMBL187717  ...  5.698970
# ..                 ...  ...       ...
# 128      CHEMBL2146517  ...  4.974694
# 129       CHEMBL187460  ...  4.995679
# 130       CHEMBL363535  ...  4.939302
# 131       CHEMBL227075  ...  4.970616
# 132        CHEMBL45830  ...  4.102923
#
# [133 rows x 8 columns]

# %%
df_final.pIC50.describe()
# Out:
# count    133.000000
# mean       4.060148
# std        1.783762
# min        1.000000
# 25%        3.522879
# 50%        4.628932
# 75%        4.970616
# max        7.301030
# Name: pIC50, dtype: float64

# %%
#emoving the intermediate bioactivity class

df_2class = df_final[df_final.bioactivity_class != 'intermediate']
df_2class
# Out:
#     molecule_chembl_id  ...     pIC50
# 2         CHEMBL185698  ...  4.869666
# 3         CHEMBL426082  ...  4.882397
# 5         CHEMBL365134  ...  6.008774
# 7         CHEMBL190743  ...  6.022276
# 8         CHEMBL365469  ...  4.950782
# ..                 ...  ...       ...
# 128      CHEMBL2146517  ...  4.974694
# 129       CHEMBL187460  ...  4.995679
# 130       CHEMBL363535  ...  4.939302
# 131       CHEMBL227075  ...  4.970616
# 132        CHEMBL45830  ...  4.102923
#
# [119 rows x 8 columns]

# %% [markdown]
# explaratory data analysis

# %% [markdown]
# As ***Jose Madina franco*** said each chemical compound can be thought of as stars and each activated molecule can be compared to constillation.

# %%
import seaborn as sns
sns.set(style = 'ticks')
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5.5,5.5))

sns.countplot(x = 'bioactivity_class', data=df_2class, edgecolor = 'black')

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('Frequency', fontsize=14, fontweight='bold')

plt.savefig('plot_bioactivity_class.pdf')

# %% [markdown]
# scatter plot of Molecular weight vs LogP

# %%
plt.figure(figsize=(5.5, 5.5))

sns.scatterplot(x='MW', y='LogP', data=df_2class, hue='bioactivity_class', size='pIC50', edgecolor='black', alpha=0.7)

plt.xlabel('MW', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('plot_MW_vs_LogP.pdf')

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'bioactivity_class', y = 'pIC50', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('pIC50 value', fontsize=14, fontweight='bold')

plt.savefig('plot_ic50.pdf')

# %% [markdown]
# statistical analysis|Mann-Whitney U Test

# %%
def mannwhitney(descriptor, verbose=False):
  # https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
  from numpy.random import seed
  from numpy.random import randn
  from scipy.stats import mannwhitneyu

# seed the random number generator
  seed(1)

# actives and inactives
  selection = [descriptor, 'bioactivity_class']
  df = df_2class[selection]
  active = df[df.bioactivity_class == 'active']
  active = active[descriptor]

  selection = [descriptor, 'bioactivity_class']
  df = df_2class[selection]
  inactive = df[df.bioactivity_class == 'inactive']
  inactive = inactive[descriptor]

# compare samples
  stat, p = mannwhitneyu(active, inactive)
  #print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
  alpha = 0.05
  if p > alpha:
    interpretation = 'Same distribution (fail to reject H0)'
  else:
    interpretation = 'Different distribution (reject H0)'
  
  results = pd.DataFrame({'Descriptor':descriptor,
                          'Statistics':stat,
                          'p':p,
                          'alpha':alpha,
                          'Interpretation':interpretation}, index=[0])
  filename = 'mannwhitneyu_' + descriptor + '.csv'
  results.to_csv(filename)

  return results

# %%
mannwhitney('pIC50')
# Out:
#   Descriptor  Statistics  ...  alpha                      Interpretation
# 0      pIC50         0.0  ...   0.05  Different distribution (reject H0)
#
# [1 rows x 5 columns]

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'bioactivity_class', y = 'MW', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('MW', fontsize=14, fontweight='bold')

plt.savefig('plot_MW.pdf')

# %%
mannwhitney('MW')
# Out:
#   Descriptor  Statistics         p  alpha                      Interpretation
# 0         MW       409.5  0.001525   0.05  Different distribution (reject H0)

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'bioactivity_class', y = 'LogP', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')

plt.savefig('plot_LogP.pdf')

# %%
mannwhitney('LogP')
# Out:
#   Descriptor  Statistics  ...  alpha                         Interpretation
# 0       LogP       712.5  ...   0.05  Same distribution (fail to reject H0)
#
# [1 rows x 5 columns]

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'bioactivity_class', y = 'NumHDonors', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHDonors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHDonors.pdf')

# %%
mannwhitney('NumHDonors')
# Out:
#    Descriptor  Statistics         p  alpha                      Interpretation
# 0  NumHDonors       299.5  0.000024   0.05  Different distribution (reject H0)

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'bioactivity_class', y = 'NumHAcceptors', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHAcceptors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHAcceptors.pdf')

# %%
mannwhitney('NumHAcceptors')
# Out:
#       Descriptor  Statistics  ...  alpha                      Interpretation
# 0  NumHAcceptors       415.0  ...   0.05  Different distribution (reject H0)
#
# [1 rows x 5 columns]

# %%
! zip -r results.zip . -i *.csv *.pdf
# Out:
# Scanning files .....
#   adding: plot_NumHAcceptors.pdf (deflated 37%)
#   adding: mannwhitneyu_pIC50.csv (deflated 10%)
#   adding: mannwhitneyu_MW.csv (deflated 9%)
#   adding: plot_ic50.pdf (deflated 37%)
#   adding: plot_NumHDonors.pdf (deflated 38%)
#   adding: plot_LogP.pdf (deflated 37%)
#   adding: bioactivity_preprocessed_data.csv (deflated 80%)
#   adding: plot_MW.pdf (deflated 38%)
#   adding: mannwhitneyu_NumHAcceptors.csv (deflated 12%)
#   adding: plot_bioactivity_class.pdf (deflated 38%)
#   adding: mannwhitneyu_NumHDonors.csv (deflated 9%)
#   adding: bioactivity_data.csv (deflated 90%)
#   adding: mannwhitneyu_LogP.csv (deflated 7%)
#   adding: plot_MW_vs_LogP.pdf (deflated 15%)

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# --2021-01-24 05:41:08--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip [following]
# --2021-01-24 05:41:08--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip’
#
# padel.zip           100%[===================>]  24.57M  85.1MB/s    in 0.3s
#
# 2021-01-24 05:41:10 (85.1 MB/s) - ‘padel.zip’ saved [25768637/25768637]
#
# --2021-01-24 05:41:10--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.sh [following]
# --2021-01-24 05:41:10--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 231 [text/plain]
# Saving to: ‘padel.sh’
#
# padel.sh            100%[===================>]     231  --.-KB/s    in 0s
#
# 2021-01-24 05:41:11 (7.62 MB/s) - ‘padel.sh’ saved [231/231]

# %%
# !unzip padel.zip
# Out:
# Archive:  padel.zip
#    creating: PaDEL-Descriptor/
#   inflating: __MACOSX/._PaDEL-Descriptor
#   inflating: PaDEL-Descriptor/MACCSFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._MACCSFingerprinter.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprinter.xml
#   inflating: PaDEL-Descriptor/EStateFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._EStateFingerprinter.xml
#   inflating: PaDEL-Descriptor/Fingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._Fingerprinter.xml
#   inflating: PaDEL-Descriptor/.DS_Store
#   inflating: __MACOSX/PaDEL-Descriptor/._.DS_Store
#    creating: PaDEL-Descriptor/license/
#   inflating: __MACOSX/PaDEL-Descriptor/._license
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprintCount.xml
#   inflating: PaDEL-Descriptor/config
#   inflating: __MACOSX/PaDEL-Descriptor/._config
#   inflating: PaDEL-Descriptor/PubchemFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._PubchemFingerprinter.xml
#   inflating: PaDEL-Descriptor/ExtendedFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._ExtendedFingerprinter.xml
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprinter.xml
#   inflating: PaDEL-Descriptor/GraphOnlyFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._GraphOnlyFingerprinter.xml
#   inflating: PaDEL-Descriptor/SubstructureFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._SubstructureFingerprinter.xml
#   inflating: PaDEL-Descriptor/Descriptors.xls
#   inflating: __MACOSX/PaDEL-Descriptor/._Descriptors.xls
#    creating: PaDEL-Descriptor/lib/
#   inflating: __MACOSX/PaDEL-Descriptor/._lib
#   inflating: PaDEL-Descriptor/PaDEL-Descriptor.jar
#   inflating: __MACOSX/PaDEL-Descriptor/._PaDEL-Descriptor.jar
#   inflating: PaDEL-Descriptor/SubstructureFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._SubstructureFingerprintCount.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprintCount.xml
#   inflating: PaDEL-Descriptor/descriptors.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._descriptors.xml
#   inflating: PaDEL-Descriptor/license/lgpl-2.1.txt
#   inflating: __MACOSX/PaDEL-Descriptor/license/._lgpl-2.1.txt
#   inflating: PaDEL-Descriptor/license/LICENSE.txt
#   inflating: __MACOSX/PaDEL-Descriptor/license/._LICENSE.txt
#   inflating: PaDEL-Descriptor/license/README - CDK
#   inflating: __MACOSX/PaDEL-Descriptor/license/._README - CDK
#   inflating: PaDEL-Descriptor/license/lgpl.license
#   inflating: __MACOSX/PaDEL-Descriptor/license/._lgpl.license
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(3).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(6).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL.jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(4).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(2).jar
#   inflating: PaDEL-Descriptor/lib/xom-1.1(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._xom-1.1(1).jar
#   inflating: PaDEL-Descriptor/lib/swing-worker-1.1.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._swing-worker-1.1.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(3).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(5).jar
#   inflating: PaDEL-Descriptor/lib/jama(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(1).jar
#   inflating: PaDEL-Descriptor/lib/appframework-1.0.3.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._appframework-1.0.3.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(7).jar
#   inflating: PaDEL-Descriptor/lib/vecmath1.2-1.14.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._vecmath1.2-1.14.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(6).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(2).jar
#   inflating: PaDEL-Descriptor/lib/jama(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(6).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(2).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(3).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(4).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-base-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-base-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(1).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(8).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(8).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(1).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(4).jar
#   inflating: PaDEL-Descriptor/lib/xom-1.1.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._xom-1.1.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(5).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(2).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(3).jar
#   inflating: PaDEL-Descriptor/lib/jama(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(7).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(6).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(1).jar
#   inflating: PaDEL-Descriptor/lib/jama(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(4).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(2).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(3).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(2).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(3).jar
#   inflating: PaDEL-Descriptor/lib/l2fprod-common-all(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._l2fprod-common-all(1).jar
#   inflating: PaDEL-Descriptor/lib/jama.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama.jar
#   inflating: PaDEL-Descriptor/lib/l2fprod-common-all.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._l2fprod-common-all.jar
#   inflating: PaDEL-Descriptor/lib/jama(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(5).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(1).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(7).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(4).jar
#   inflating: PaDEL-Descriptor/lib/cdk-1.4.15.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._cdk-1.4.15.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(5).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(1).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(8).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(8).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(6).jar
#   inflating: PaDEL-Descriptor/lib/jama(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(2).jar
#   inflating: PaDEL-Descriptor/lib/jama(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(3).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(1).jar
#   inflating: PaDEL-Descriptor/lib/guava-17.0.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._guava-17.0.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(4).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(5).jar

# %%
! wget https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv
# Out:
# --2021-01-24 05:41:11--  https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 655414 (640K) [text/plain]
# Saving to: ‘acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv’
#
# acetylcholinesteras 100%[===================>] 640.05K  --.-KB/s    in 0.03s
#
# 2021-01-24 05:41:12 (19.5 MB/s) - ‘acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv’ saved [655414/655414]

# %%
df3 = pd.read_csv('acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv')

# %%
selection = ['canonical_smiles', 'molecule_chembl_id']
df3_selection = df[selection]
df3_selection.to_csv('molecule.smi',sep='\t', index=False, header=False)

# %%
! cat molecule.smi | head -5
# Out:
# Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21	CHEMBL187579
# O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21	CHEMBL188487
# O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21	CHEMBL185698
# O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21	CHEMBL426082
# O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]	CHEMBL187717

# %%
! cat molecule.smi | wc -l
# Out:
# 133

# %% [markdown]
# # calculate fingerprint descriptors

# %% [markdown]
# calculate PasDEL descriptors

# %%
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
! bash padel.sh
# Out:
# Processing CHEMBL187579 in molecule.smi (1/133).
# Processing CHEMBL188487 in molecule.smi (2/133).
# Processing CHEMBL185698 in molecule.smi (3/133). Average speed: 2.28 s/mol.
# Processing CHEMBL187717 in molecule.smi (5/133). Average speed: 1.10 s/mol.
# Processing CHEMBL426082 in molecule.smi (4/133). Average speed: 1.18 s/mol.
# Processing CHEMBL187598 in molecule.smi (7/133). Average speed: 0.86 s/mol.
# Processing CHEMBL365134 in molecule.smi (6/133). Average speed: 0.88 s/mol.
# Processing CHEMBL190743 in molecule.smi (8/133). Average speed: 0.75 s/mol.
# Processing CHEMBL365469 in molecule.smi (9/133). Average speed: 0.76 s/mol.
# Processing CHEMBL188983 in molecule.smi (10/133). Average speed: 0.70 s/mol.
# Processing CHEMBL191575 in molecule.smi (11/133). Average speed: 0.68 s/mol.
# Processing CHEMBL370923 in molecule.smi (12/133). Average speed: 0.68 s/mol.
# Processing CHEMBL194398 in molecule.smi (13/133). Average speed: 0.74 s/mol.
# Processing CHEMBL196635 in molecule.smi (14/133). Average speed: 0.62 s/mol.
# Processing CHEMBL209287 in molecule.smi (15/133). Average speed: 0.66 s/mol.
# Processing CHEMBL358279 in molecule.smi (16/133). Average speed: 0.63 s/mol.
# Processing CHEMBL348660 in molecule.smi (17/133). Average speed: 0.64 s/mol.
# Processing CHEMBL379727 in molecule.smi (18/133). Average speed: 0.59 s/mol.
# Processing CHEMBL210525 in molecule.smi (19/133). Average speed: 0.57 s/mol.
# Processing CHEMBL148483 in molecule.smi (20/133). Average speed: 0.54 s/mol.
# Processing CHEMBL383725 in molecule.smi (21/133). Average speed: 0.52 s/mol.
# Processing CHEMBL118596 in molecule.smi (22/133). Average speed: 0.50 s/mol.
# Processing CHEMBL208732 in molecule.smi (23/133). Average speed: 0.49 s/mol.
# Processing CHEMBL208732 in molecule.smi (24/133). Average speed: 0.48 s/mol.
# Processing CHEMBL210146 in molecule.smi (25/133). Average speed: 0.47 s/mol.
# Processing CHEMBL210146 in molecule.smi (26/133). Average speed: 0.47 s/mol.
# Processing CHEMBL207458 in molecule.smi (27/133). Average speed: 0.46 s/mol.
# Processing CHEMBL207484 in molecule.smi (29/133). Average speed: 0.44 s/mol.
# Processing CHEMBL207458 in molecule.smi (28/133). Average speed: 0.45 s/mol.
# Processing CHEMBL207207 in molecule.smi (31/133). Average speed: 0.42 s/mol.
# Processing CHEMBL207484 in molecule.smi (30/133). Average speed: 0.42 s/mol.
# Processing CHEMBL207207 in molecule.smi (32/133). Average speed: 0.42 s/mol.
# Processing CHEMBL210487 in molecule.smi (33/133). Average speed: 0.41 s/mol.
# Processing CHEMBL210487 in molecule.smi (34/133). Average speed: 0.41 s/mol.
# Processing CHEMBL380470 in molecule.smi (35/133). Average speed: 0.40 s/mol.
# Processing CHEMBL380470 in molecule.smi (36/133). Average speed: 0.40 s/mol.
# Processing CHEMBL210612 in molecule.smi (37/133). Average speed: 0.39 s/mol.
# Processing CHEMBL210612 in molecule.smi (38/133). Average speed: 0.39 s/mol.
# Processing CHEMBL209667 in molecule.smi (39/133). Average speed: 0.38 s/mol.
# Processing CHEMBL209667 in molecule.smi (40/133). Average speed: 0.38 s/mol.
# Processing CHEMBL210097 in molecule.smi (41/133). Average speed: 0.38 s/mol.
# Processing CHEMBL210097 in molecule.smi (42/133). Average speed: 0.39 s/mol.
# Processing CHEMBL378674 in molecule.smi (43/133). Average speed: 0.39 s/mol.
# Processing CHEMBL378674 in molecule.smi (44/133). Average speed: 0.38 s/mol.
# Processing CHEMBL210216 in molecule.smi (45/133). Average speed: 0.37 s/mol.
# Processing CHEMBL210216 in molecule.smi (46/133). Average speed: 0.37 s/mol.
# Processing CHEMBL210195 in molecule.smi (47/133). Average speed: 0.36 s/mol.
# Processing CHEMBL210195 in molecule.smi (48/133). Average speed: 0.36 s/mol.
# Processing CHEMBL210437 in molecule.smi (49/133). Average speed: 0.35 s/mol.
# Processing CHEMBL378677 in molecule.smi (51/133). Average speed: 0.35 s/mol.
# Processing CHEMBL210437 in molecule.smi (50/133). Average speed: 0.35 s/mol.
# Processing CHEMBL378677 in molecule.smi (52/133). Average speed: 0.35 s/mol.
# Processing CHEMBL210972 in molecule.smi (53/133). Average speed: 0.35 s/mol.
# Processing CHEMBL210972 in molecule.smi (54/133). Average speed: 0.35 s/mol.
# Processing CHEMBL210145 in molecule.smi (55/133). Average speed: 0.35 s/mol.
# Processing CHEMBL377225 in molecule.smi (57/133). Average speed: 0.34 s/mol.
# Processing CHEMBL210145 in molecule.smi (56/133). Average speed: 0.34 s/mol.
# Processing CHEMBL377225 in molecule.smi (58/133). Average speed: 0.34 s/mol.
# Processing CHEMBL210823 in molecule.smi (59/133). Average speed: 0.34 s/mol.
# Processing CHEMBL207381 in molecule.smi (61/133). Average speed: 0.34 s/mol.
# Processing CHEMBL210823 in molecule.smi (60/133). Average speed: 0.33 s/mol.
# Processing CHEMBL207381 in molecule.smi (62/133). Average speed: 0.33 s/mol.
# Processing CHEMBL210511 in molecule.smi (63/133). Average speed: 0.34 s/mol.
# Processing CHEMBL210511 in molecule.smi (64/133). Average speed: 0.34 s/mol.
# Processing CHEMBL210632 in molecule.smi (65/133). Average speed: 0.33 s/mol.
# Processing CHEMBL210497 in molecule.smi (67/133). Average speed: 0.33 s/mol.
# Processing CHEMBL210632 in molecule.smi (66/133). Average speed: 0.33 s/mol.
# Processing CHEMBL210497 in molecule.smi (68/133). Average speed: 0.33 s/mol.
# Processing CHEMBL208584 in molecule.smi (69/133). Average speed: 0.32 s/mol.
# Processing CHEMBL208584 in molecule.smi (70/133). Average speed: 0.32 s/mol.
# Processing CHEMBL208763 in molecule.smi (71/133). Average speed: 0.33 s/mol.
# Processing CHEMBL208763 in molecule.smi (72/133). Average speed: 0.32 s/mol.
# Processing CHEMBL209227 in molecule.smi (73/133). Average speed: 0.32 s/mol.
# Processing CHEMBL209227 in molecule.smi (74/133). Average speed: 0.32 s/mol.
# Processing CHEMBL210092 in molecule.smi (76/133). Average speed: 0.31 s/mol.
# Processing CHEMBL210092 in molecule.smi (75/133). Average speed: 0.32 s/mol.
# Processing CHEMBL377150 in molecule.smi (77/133). Average speed: 0.31 s/mol.
# Processing CHEMBL377150 in molecule.smi (78/133). Average speed: 0.31 s/mol.
# Processing CHEMBL212454 in molecule.smi (79/133). Average speed: 0.31 s/mol.
# Processing CHEMBL213581 in molecule.smi (80/133). Average speed: 0.31 s/mol.
# Processing CHEMBL380403 in molecule.smi (81/133). Average speed: 0.31 s/mol.
# Processing CHEMBL212504 in molecule.smi (82/133). Average speed: 0.31 s/mol.
# Processing CHEMBL384739 in molecule.smi (84/133). Average speed: 0.30 s/mol.
# Processing CHEMBL211969 in molecule.smi (83/133). Average speed: 0.31 s/mol.
# Processing CHEMBL212240 in molecule.smi (86/133). Average speed: 0.30 s/mol.
# Processing CHEMBL215732 in molecule.smi (85/133). Average speed: 0.30 s/mol.
# Processing CHEMBL377253 in molecule.smi (87/133). Average speed: 0.30 s/mol.
# Processing CHEMBL215397 in molecule.smi (88/133). Average speed: 0.30 s/mol.
# Processing CHEMBL378342 in molecule.smi (89/133). Average speed: 0.30 s/mol.
# Processing CHEMBL379642 in molecule.smi (90/133). Average speed: 0.29 s/mol.
# Processing CHEMBL427404 in molecule.smi (91/133). Average speed: 0.29 s/mol.
# Processing CHEMBL212190 in molecule.smi (92/133). Average speed: 0.29 s/mol.
# Processing CHEMBL378700 in molecule.smi (93/133). Average speed: 0.29 s/mol.
# Processing CHEMBL212019 in molecule.smi (94/133). Average speed: 0.29 s/mol.
# Processing CHEMBL212399 in molecule.smi (95/133). Average speed: 0.29 s/mol.
# Processing CHEMBL215733 in molecule.smi (96/133). Average speed: 0.29 s/mol.
# Processing CHEMBL375130 in molecule.smi (97/133). Average speed: 0.28 s/mol.
# Processing CHEMBL214372 in molecule.smi (98/133). Average speed: 0.28 s/mol.
# Processing CHEMBL212218 in molecule.smi (99/133). Average speed: 0.28 s/mol.
# Processing CHEMBL222840 in molecule.smi (100/133). Average speed: 0.28 s/mol.
# Processing CHEMBL222769 in molecule.smi (101/133). Average speed: 0.28 s/mol.
# Processing CHEMBL222735 in molecule.smi (102/133). Average speed: 0.27 s/mol.
# Processing CHEMBL222628 in molecule.smi (103/133). Average speed: 0.27 s/mol.
# Processing CHEMBL222893 in molecule.smi (104/133). Average speed: 0.27 s/mol.
# Processing CHEMBL225515 in molecule.smi (105/133). Average speed: 0.27 s/mol.
# Processing CHEMBL222234 in molecule.smi (106/133). Average speed: 0.27 s/mol.
# Processing CHEMBL187266 in molecule.smi (108/133). Average speed: 0.27 s/mol.
# Processing CHEMBL426898 in molecule.smi (107/133). Average speed: 0.27 s/mol.
# Processing CHEMBL215254 in molecule.smi (109/133). Average speed: 0.27 s/mol.
# Processing CHEMBL2146517 in molecule.smi (110/133). Average speed: 0.27 s/mol.
# Processing CHEMBL363535 in molecule.smi (112/133). Average speed: 0.27 s/mol.
# Processing CHEMBL187460 in molecule.smi (111/133). Average speed: 0.27 s/mol.
# Processing CHEMBL45830 in molecule.smi (114/133). Average speed: 0.27 s/mol.
# Processing CHEMBL227075 in molecule.smi (113/133). Average speed: 0.27 s/mol.
# Processing CHEMBL215254 in molecule.smi (116/133). Average speed: 0.27 s/mol.
# Processing CHEMBL187266 in molecule.smi (115/133). Average speed: 0.27 s/mol.
# Processing CHEMBL187460 in molecule.smi (118/133). Average speed: 0.27 s/mol.
# Processing CHEMBL2146517 in molecule.smi (117/133). Average speed: 0.27 s/mol.
# Processing CHEMBL227075 in molecule.smi (120/133). Average speed: 0.27 s/mol.
# Processing CHEMBL363535 in molecule.smi (119/133). Average speed: 0.27 s/mol.
# Processing CHEMBL45830 in molecule.smi (121/133). Average speed: 0.27 s/mol.
# Processing CHEMBL187460 in molecule.smi (123/133). Average speed: 0.27 s/mol.
# Processing CHEMBL215254 in molecule.smi (122/133). Average speed: 0.27 s/mol.
# Processing CHEMBL227075 in molecule.smi (125/133). Average speed: 0.27 s/mol.
# Processing CHEMBL363535 in molecule.smi (124/133). Average speed: 0.27 s/mol.
# Processing CHEMBL187266 in molecule.smi (127/133). Average speed: 0.27 s/mol.
# Processing CHEMBL45830 in molecule.smi (126/133). Average speed: 0.27 s/mol.
# Processing CHEMBL215254 in molecule.smi (128/133). Average speed: 0.27 s/mol.
# Processing CHEMBL2146517 in molecule.smi (129/133). Average speed: 0.27 s/mol.
# Processing CHEMBL187460 in molecule.smi (130/133). Average speed: 0.27 s/mol.
# Processing CHEMBL363535 in molecule.smi (131/133). Average speed: 0.27 s/mol.
# Processing CHEMBL227075 in molecule.smi (132/133). Average speed: 0.27 s/mol.
# Processing CHEMBL45830 in molecule.smi (133/133). Average speed: 0.27 s/mol.
# Descriptor calculation completed in 35.172 secs . Average speed: 0.26 s/mol.

# %%
# !ls -l
# Out:
# total 109480
# -rw-r--r-- 1 root root   655414 Jan 24 05:41 acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv
# -rw-r--r-- 1 root root    70010 Jan 24 05:38 bioactivity_data.csv
# -rw-r--r-- 1 root root    10567 Jan 24 05:39 bioactivity_preprocessed_data.csv
# -rw-r--r-- 1 root root   247688 Jan 24 05:41 descriptors_output.csv
# drwx------ 5 root root     4096 Jan 24 05:38 gdrive
# drwxr-xr-x 3 root root     4096 Jan 24 05:41 __MACOSX
# -rw-r--r-- 1 root root      121 Jan 24 05:40 mannwhitneyu_LogP.csv
# -rw-r--r-- 1 root root      119 Jan 24 05:40 mannwhitneyu_MW.csv
# -rw-r--r-- 1 root root      130 Jan 24 05:40 mannwhitneyu_NumHAcceptors.csv
# -rw-r--r-- 1 root root      128 Jan 24 05:40 mannwhitneyu_NumHDonors.csv
# -rw-r--r-- 1 root root      121 Jan 24 05:40 mannwhitneyu_pIC50.csv
# -rwxr-xr-x 1 root root 85055499 Mar 11  2020 Miniconda3-py37_4.8.2-Linux-x86_64.sh
# -rw-r--r-- 1 root root     7991 Jan 24 05:41 molecule.smi
# drwxrwxr-x 4 root root     4096 May 30  2020 PaDEL-Descriptor
# -rw-r--r-- 1 root root      231 Jan 24 05:41 padel.sh
# -rw-r--r-- 1 root root 25768637 Jan 24 05:41 padel.zip
# -rw-r--r-- 1 root root    13918 Jan 24 05:40 plot_bioactivity_class.pdf
# -rw-r--r-- 1 root root    14695 Jan 24 05:40 plot_ic50.pdf
# -rw-r--r-- 1 root root    13833 Jan 24 05:40 plot_LogP.pdf
# -rw-r--r-- 1 root root    12969 Jan 24 05:40 plot_MW.pdf
# -rw-r--r-- 1 root root    35428 Jan 24 05:40 plot_MW_vs_LogP.pdf
# -rw-r--r-- 1 root root    14569 Jan 24 05:40 plot_NumHAcceptors.pdf
# -rw-r--r-- 1 root root    14059 Jan 24 05:40 plot_NumHDonors.pdf
# -rw-r--r-- 1 root root    94562 Jan 24 05:41 results.zip
# drwxr-xr-x 1 root root     4096 Jan 20 17:27 sample_data

# %%
df3_x = pd.read_csv('descriptors_output.csv')

# %%
df3_x
# Out:
#               Name  PubchemFP0  ...  PubchemFP879  PubchemFP880
# 0     CHEMBL187579           1  ...             0             0
# 1     CHEMBL188487           1  ...             0             0
# 2     CHEMBL185698           1  ...             0             0
# 3     CHEMBL426082           1  ...             0             0
# 4     CHEMBL187717           1  ...             0             0
# ..             ...         ...  ...           ...           ...
# 128  CHEMBL2146517           1  ...             0             0
# 129   CHEMBL187460           1  ...             0             0
# 130   CHEMBL227075           1  ...             0             0
# 131   CHEMBL363535           1  ...             0             0
# 132    CHEMBL45830           1  ...             0             0
#
# [133 rows x 882 columns]

# %%
df3_x = df3_x.drop(columns=['Name'])
df3_x
# Out:
#      PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0             1           1  ...             0             0
# 1             1           1  ...             0             0
# 2             1           1  ...             0             0
# 3             1           1  ...             0             0
# 4             1           1  ...             0             0
# ..          ...         ...  ...           ...           ...
# 128           1           1  ...             0             0
# 129           1           1  ...             0             0
# 130           1           1  ...             0             0
# 131           1           1  ...             0             0
# 132           1           1  ...             0             0
#
# [133 rows x 881 columns]

# %%
df3_y = df3['pIC50']
df3_y
# Out:
# 0       6.124939
# 1       7.000000
# 2       4.301030
# 3       6.522879
# 4       6.096910
#           ...
# 4690    5.612610
# 4691    5.595166
# 4692    5.419075
# 4693    5.460924
# 4694    5.555955
# Name: pIC50, Length: 4695, dtype: float64

# %%
dataset3 = pd.concat([df3_x,df3_y], axis =1)
dataset3
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0            1.0         1.0         0.0  ...           0.0           0.0  6.124939
# 1            1.0         1.0         0.0  ...           0.0           0.0  7.000000
# 2            1.0         1.0         0.0  ...           0.0           0.0  4.301030
# 3            1.0         1.0         0.0  ...           0.0           0.0  6.522879
# 4            1.0         1.0         0.0  ...           0.0           0.0  6.096910
# ...          ...         ...         ...  ...           ...           ...       ...
# 4690         NaN         NaN         NaN  ...           NaN           NaN  5.612610
# 4691         NaN         NaN         NaN  ...           NaN           NaN  5.595166
# 4692         NaN         NaN         NaN  ...           NaN           NaN  5.419075
# 4693         NaN         NaN         NaN  ...           NaN           NaN  5.460924
# 4694         NaN         NaN         NaN  ...           NaN           NaN  5.555955
#
# [4695 rows x 882 columns]

# %%
dataset3.to_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv', index=False)

# %%
from sklearn.model_selection import train_test_split as tts
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# you can also download the data base from the github page of data proffessor, great guy

# %%
! wget https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Out:
# --2021-01-24 05:59:25--  https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv [following]
# --2021-01-24 05:59:26--  https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8363909 (8.0M) [text/plain]
# Saving to: ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv.2’
#
# acetylcholinesteras 100%[===================>]   7.98M  51.9MB/s    in 0.2s
#
# 2021-01-24 05:59:27 (51.9 MB/s) - ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv.2’ saved [8363909/8363909]

# %%
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
x = df.drop('pIC50', axis =1)
x
#IC50 -> inhibition concentration at 50%
#pIC50 -> negative log of IC50
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0              1           1  ...             0             0
# 1              1           1  ...             0             0
# 2              1           1  ...             0             0
# 3              1           1  ...             0             0
# 4              1           1  ...             0             0
# ...          ...         ...  ...           ...           ...
# 4690           1           1  ...             0             0
# 4691           1           1  ...             0             0
# 4692           1           1  ...             0             0
# 4693           1           1  ...             0             0
# 4694           1           1  ...             0             0
#
# [4695 rows x 881 columns]

# %%
y = df.pIC50
y
# Out:
# 0       6.124939
# 1       7.000000
# 2       4.301030
# 3       6.522879
# 4       6.096910
#           ...
# 4690    5.612610
# 4691    5.595166
# 4692    5.419075
# 4693    5.460924
# 4694    5.555955
# Name: pIC50, Length: 4695, dtype: float64

# %%
x.shape
# Out:
# (4695, 881)

# %%
y.shape
# Out:
# (4695,)

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
x = selection.fit_transform(x)

# %%
x.shape
# Out:
# (4695, 137)

# %%
X_train, X_test, Y_train, Y_test = tts(x,y, test_size=0.2)

# %%
X_train.shape, Y_train.shape
# Out:
# ((3756, 137), (3756,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((939, 137), (939,))

# %%
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, Y_train)
r2 = model.score(X_test, Y_test)
r2
# Out:
# 0.5374343961717047

# %%
Y_pred = model.predict(X_test)

import seaborn as sns
import matplotlib.pyplot as plt

sns.set(color_codes=True)
sns.set_style("white")

ax = sns.regplot(Y_test, Y_pred, scatter_kws={'alpha':0.4})
ax.set_xlabel('Experimental pIC50', fontsize='large', fontweight='bold')
ax.set_ylabel('Predicted pIC50', fontsize='large', fontweight='bold')
ax.set_xlim(0, 12)
ax.set_ylim(0, 12)
ax.figure.set_size_inches(5, 5)
plt.show
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <function matplotlib.pyplot.show>
